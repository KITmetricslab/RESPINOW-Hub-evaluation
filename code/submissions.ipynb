# %%
import os
import pandas as pd
from pathlib import Path

# %%
def list_submissions():
    root_dir = Path('../submissions')
    data = []

    for file_path in root_dir.rglob('*.csv'):
        # Expecting path: submissions/source/disease/model/file.csv
        try:
            source = file_path.parts[2]
            disease = file_path.parts[3]
            model = file_path.parts[4]
            filename = file_path.name

            data.append({
                'source': source,
                'disease': disease,
                'model': model,
                'filename': filename
            })
        except IndexError:
            print(f"Skipping malformed path: {file_path}")

    df = pd.DataFrame(data)

    df['date'] = df.filename.apply(lambda x: x[:10])
    df = df[df.date.between('2024-10-17', '2025-03-27')]
    df = df[~df.date.isin(['2024-12-26', '2025-01-02'])]
    df = df[~((df.model == 'MPIDS-PS_embedding') & (df.source == 'survstat'))]
    
    return df

# %%
df = list_submissions()

# %%
df
# Out:
#        source    disease               model  \
# 0         agi        are  MPIDS-PS_embedding
# 1         agi        are  MPIDS-PS_embedding
# 2         agi        are  MPIDS-PS_embedding
# 3         agi        are  MPIDS-PS_embedding
# 4         agi        are  MPIDS-PS_embedding
# ..        ...        ...                 ...
# 911  survstat  influenza      KIT-epinowcast
# 913  survstat  influenza      KIT-epinowcast
# 914  survstat  influenza      KIT-epinowcast
# 915  survstat  influenza      KIT-epinowcast
# 916  survstat  influenza      KIT-epinowcast
#
#                                              filename        date
# 0           2025-02-13-agi-are-MPIDS-PS_embedding.csv  2025-02-13
# 1           2025-03-13-agi-are-MPIDS-PS_embedding.csv  2025-03-13
# 2           2024-10-17-agi-are-MPIDS-PS_embedding.csv  2024-10-17
# 3           2024-11-07-agi-are-MPIDS-PS_embedding.csv  2024-11-07
# 4           2024-12-19-agi-are-MPIDS-PS_embedding.csv  2024-12-19
# ..                                                ...         ...
# 911  2024-11-28-survstat-influenza-KIT-epinowcast.csv  2024-11-28
# 913  2025-02-06-survstat-influenza-KIT-epinowcast.csv  2025-02-06
# 914  2025-01-09-survstat-influenza-KIT-epinowcast.csv  2025-01-09
# 915  2025-03-13-survstat-influenza-KIT-epinowcast.csv  2025-03-13
# 916  2025-03-20-survstat-influenza-KIT-epinowcast.csv  2025-03-20
#
# [415 rows x 5 columns]

# %%
df.groupby(['source', 'disease', 'model'])['date'].nunique().reset_index(name='n_dates')
# Out:
#       source    disease               model  n_dates
# 0        agi        are        KIT-LightGBM       22
# 1        agi        are         KIT-TSMixer       22
# 2        agi        are            KIT-hhh4       22
# 3        agi        are  KIT-simple_nowcast       22
# 4        agi        are  MPIDS-PS_embedding       22
# 5    icosari       sari        KIT-LightGBM       22
# 6    icosari       sari    KIT-MeanEnsemble       22
# 7    icosari       sari         KIT-TSMixer       22
# 8    icosari       sari      KIT-epinowcast       22
# 9    icosari       sari            KIT-hhh4       22
# 10   icosari       sari  KIT-simple_nowcast       22
# 11   icosari       sari  MPIDS-PS_embedding       22
# 12   icosari       sari            RIVM-GAM       22
# 13  survstat  influenza        HZI-ODEmodel       22
# 14  survstat  influenza      KIT-epinowcast       21
# 15  survstat  influenza  KIT-simple_nowcast       22
# 16  survstat  influenza            RIVM-GAM       21
# 17  survstat        rsv        HZI-ODEmodel       22
# 18  survstat        rsv  KIT-simple_nowcast       21

# %%
# influenza: KIT-epinowcast, RIVM-GAM: 2024-11-21 
# rsv: KIT-simple_nowcast: 2025-01-30

# %%
def combine_submissions():
    df_submissions = list_submissions()
      
    dfs = []
    for _, row in df_submissions.iterrows():
        file_path = f"../submissions/{row['source']}/{row['disease']}/{row['model']}/{row['filename']}"
        
        if os.path.exists(file_path):
            try:
                df_temp = pd.read_csv(file_path)
                df_temp['source'] = row['source']
                df_temp['disease'] = row['disease']
                df_temp['model'] = row['model']
                dfs.append(df_temp)
            except Exception as e:
                print(f"Failed to load {file_path}: {e}")
        else:
            print(f"File not found: {file_path}")

    return pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()

# %%
def determine_level(row):
    if row['location'] == 'DE' and row['age_group'] == '00+':
        return 'national'
    elif row['location'] != 'DE':
        return 'states'
    elif row['location'] == 'DE' and row['age_group'] != '00+':
        return 'age'
    else:
        return 'unknown'

# %%
df = combine_submissions()

# %%
df['level'] = df.apply(determine_level, axis=1)

# %%
df.to_csv('../data/submissions.csv', index=False)

# %%
df[(df.location == 'DE') & (df.age_group == '00+') & (df.type == 'quantile')].groupby(['source', 'disease', 'model']).size().reset_index(name='size')
# Out:
#       source    disease               model  size
# 0        agi        are        KIT-LightGBM   616
# 1        agi        are         KIT-TSMixer   616
# 2        agi        are            KIT-hhh4   616
# 3        agi        are  KIT-simple_nowcast  1768
# 4        agi        are  MPIDS-PS_embedding   616
# 5    icosari       sari        KIT-LightGBM   616
# 6    icosari       sari    KIT-MeanEnsemble   616
# 7    icosari       sari         KIT-TSMixer   616
# 8    icosari       sari      KIT-epinowcast   616
# 9    icosari       sari            KIT-hhh4   616
# 10   icosari       sari  KIT-simple_nowcast  1768
# 11   icosari       sari  MPIDS-PS_embedding   616
# 12   icosari       sari            RIVM-GAM   616
# 13  survstat  influenza        HZI-ODEmodel   616
# 14  survstat  influenza      KIT-epinowcast   588
# 15  survstat  influenza  KIT-simple_nowcast  2210
# 16  survstat  influenza            RIVM-GAM   728
# 17  survstat        rsv        HZI-ODEmodel   616
# 18  survstat        rsv  KIT-simple_nowcast  2015

# %%
df[(df.location == 'DE') & (df.type == 'quantile')].groupby(['source', 'disease', 'model']).size().reset_index(name='size')
# Out:
#       source    disease               model   size
# 0        agi        are        KIT-LightGBM   3696
# 1        agi        are         KIT-TSMixer   3696
# 2        agi        are            KIT-hhh4   3696
# 3        agi        are  KIT-simple_nowcast  10608
# 4        agi        are  MPIDS-PS_embedding    616
# 5    icosari       sari        KIT-LightGBM   4312
# 6    icosari       sari    KIT-MeanEnsemble   4312
# 7    icosari       sari         KIT-TSMixer   4312
# 8    icosari       sari      KIT-epinowcast   4312
# 9    icosari       sari            KIT-hhh4   4312
# 10   icosari       sari  KIT-simple_nowcast  12376
# 11   icosari       sari  MPIDS-PS_embedding    616
# 12   icosari       sari            RIVM-GAM   4312
# 13  survstat  influenza        HZI-ODEmodel   4312
# 14  survstat  influenza      KIT-epinowcast   4116
# 15  survstat  influenza  KIT-simple_nowcast  15470
# 16  survstat  influenza            RIVM-GAM   5096
# 17  survstat        rsv        HZI-ODEmodel   4312
# 18  survstat        rsv  KIT-simple_nowcast  14105

# %%
df[(df.source == 'icosari') & (df.location == 'DE') & (df.model == 'KIT-MeanEnsemble')].groupby('forecast_date').size()
# Out:
# forecast_date
# 2024-10-17    196
# 2024-10-24    196
# 2024-10-31    196
# 2024-11-07    196
# 2024-11-14    196
# 2024-11-21    196
# 2024-11-28    196
# 2024-12-05    196
# 2024-12-12    196
# 2024-12-19    196
# 2025-01-09    196
# 2025-01-16    196
# 2025-01-23    196
# 2025-01-30    196
# 2025-02-06    196
# 2025-02-13    196
# 2025-02-20    196
# 2025-02-27    196
# 2025-03-06    196
# 2025-03-13    196
# 2025-03-20    196
# 2025-03-27    196
# dtype: int64

# %%
df[(df.source == 'icosari') & (df.location == 'DE') & (df.model == 'KIT-MeanEnsemble')].groupby('forecast_date').size()
# Out:
# forecast_date
# 2024-10-17    196
# 2024-10-24    196
# 2024-10-31    196
# 2024-11-07    196
# 2024-11-14    196
# 2024-11-21    196
# 2024-11-28    196
# 2024-12-05    196
# 2024-12-12    196
# 2024-12-19    196
# 2025-01-09    196
# 2025-01-16    196
# 2025-01-23    196
# 2025-01-30    196
# 2025-02-06    196
# 2025-02-13    196
# 2025-02-20    196
# 2025-02-27    196
# 2025-03-06    392
# 2025-03-13    196
# 2025-03-20    196
# 2025-03-27    196
# dtype: int64
